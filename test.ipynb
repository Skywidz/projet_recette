# %%
print("hello wolrd")
# Out:
# hello wolrd

# %%
import numpy

# %%
import pandas

# %%
df = pandas.read_excel("/Users/skywidz/Desktop/PROJET_AGRO/data/AGRIBALYSE3.1_produits alimentaires_2.xlsm", sheet_name='Detail ingredient')
df
# Out:
#         Unnamed: 0     Unnamed: 1  \
# 0              NaN            NaN
# 1              NaN            NaN
# 2     Ciqual \nAGB  Ciqual \ncode
# 3            37000          37000
# 4            37000          37000
# ...            ...            ...
# 6854         25512          25512
# 6855         25512          25512
# 6856         25512          25512
# 6857         25512          25512
# 6858         25512          25512
#
#      Résultats par ingrédient\n(pour les aliments "recettes" seulement)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                      Groupe d'aliment
# 3                aides culinaires et ingrédients divers
# 4                aides culinaires et ingrédients divers
# ...                                                 ...
# 6854                            viandes, œufs, poissons
# 6855                            viandes, œufs, poissons
# ...
