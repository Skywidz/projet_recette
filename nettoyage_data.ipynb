# %%
import pandas as pd

# %%
df_synthese = pd.read_excel("/Users/skywidz/Desktop/PROJET_AGRO/data/AGRIBALYSE3.1_produits alimentaires_2.xlsm", sheet_name='Synthese')
df_detail_etape = pd.read_excel("/Users/skywidz/Desktop/PROJET_AGRO/data/AGRIBALYSE3.1_produits alimentaires_2.xlsm", sheet_name='Detail etape')
df_detail_ingredient = pd.read_excel("/Users/skywidz/Desktop/PROJET_AGRO/data/AGRIBALYSE3.1_produits alimentaires_2.xlsm", sheet_name='Detail ingredient')
df_synthese.head()
# Out:
#   Unnamed: 0    Unnamed: 1                              Unnamed: 2  \
# 0        NaN           NaN                                     NaN
# 1  Code\nAGB  Code\nCIQUAL                        Groupe d'aliment
# 2      11084         11084  aides culinaires et ingrédients divers
# 3      11023         11023  aides culinaires et ingrédients divers
# 4      11000         11000  aides culinaires et ingrédients divers
#
#                 Synthèse                  Unnamed: 4             Unnamed: 5  \
# 0                    NaN                         NaN                    NaN
# 1  Sous-groupe d'aliment  Nom du Produit en Français               LCI Name
# 2                 algues           Agar (algue), cru     Seaweed, agar, raw
# 3                 herbes           Ail séché, poudre  Garlic, powder, dried
# 4                 herbes                    Ail, cru          Garlic, fresh
#
#                                           Unnamed: 6  \
# ...

# %%
df_detail_etape.drop([0], inplace=True)
df_detail_etape = df_detail_etape.reset_index(drop=True)
df_detail_etape.columns = df_detail_etape.iloc[0]
df_detail_etape
# Out:
# 0     Code AGB  Code CIQUAL                        Groupe d'aliment  \
# 0     Code AGB  Code CIQUAL                        Groupe d'aliment
# 1        11084        11084  aides culinaires et ingrédients divers
# 2        11023        11023  aides culinaires et ingrédients divers
# 3        11000        11000  aides culinaires et ingrédients divers
# 4        11093        11093  aides culinaires et ingrédients divers
# ...        ...          ...                                     ...
# 2513      6535         6535                 viandes, œufs, poissons
# 2514      6582         6582                 viandes, œufs, poissons
# 2515     26146        26146                 viandes, œufs, poissons
# 2516     26147        26147                 viandes, œufs, poissons
# 2517     25512        25512                 viandes, œufs, poissons
#
# 0                Sous-groupe d'aliment            Nom du Produit en Français  \
# ...

# %%
df_detail_etape.drop([0], inplace=True)
df_detail_etape = df_detail_etape.reset_index(drop=True)
df_detail_etape
# Out:
# 0    Code AGB Code CIQUAL                        Groupe d'aliment  \
# 0       11084       11084  aides culinaires et ingrédients divers
# 1       11023       11023  aides culinaires et ingrédients divers
# 2       11000       11000  aides culinaires et ingrédients divers
# 3       11093       11093  aides culinaires et ingrédients divers
# 4       20995       20995  aides culinaires et ingrédients divers
# ...       ...         ...                                     ...
# 2512     6535        6535                 viandes, œufs, poissons
# 2513     6582        6582                 viandes, œufs, poissons
# 2514    26146       26146                 viandes, œufs, poissons
# 2515    26147       26147                 viandes, œufs, poissons
# 2516    25512       25512                 viandes, œufs, poissons
#
# 0                Sous-groupe d'aliment  \
# 0                               algues
# 1                               herbes
# 2                               herbes
# ...

# %%
df_detail_etape = df_detail_etape.iloc[:, 0:15]
df_detail_etape
# Out:
# 0    Code AGB Code CIQUAL                        Groupe d'aliment  \
# 0       11084       11084  aides culinaires et ingrédients divers
# 1       11023       11023  aides culinaires et ingrédients divers
# 2       11000       11000  aides culinaires et ingrédients divers
# 3       11093       11093  aides culinaires et ingrédients divers
# 4       20995       20995  aides culinaires et ingrédients divers
# ...       ...         ...                                     ...
# 2512     6535        6535                 viandes, œufs, poissons
# 2513     6582        6582                 viandes, œufs, poissons
# 2514    26146       26146                 viandes, œufs, poissons
# 2515    26147       26147                 viandes, œufs, poissons
# 2516    25512       25512                 viandes, œufs, poissons
#
# 0                Sous-groupe d'aliment  \
# 0                               algues
# 1                               herbes
# 2                               herbes
# ...

# %%
df_detail_etape.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Code AGB                     2517 non-null   object
#  1   Code CIQUAL                  2517 non-null   object
#  2   Groupe d'aliment             2517 non-null   object
#  3   Sous-groupe d'aliment        2517 non-null   object
#  4   Nom du Produit en Français   2517 non-null   object
#  5   LCI Name                     2517 non-null   object
#  6   DQR                          2517 non-null   object
#  7   Nom et code                  2517 non-null   object
#  8   Agriculture                  2517 non-null   object
#  9   Transformation               2517 non-null   object
#  10  Emballage                    2517 non-null   object
#  11  Transport                    2517 non-null   object
#  12  Supermarché et distribution  2517 non-null   object
# ...

# %%
df_detail_etape.columns
# Out:
# Index(['Code AGB', 'Code CIQUAL', 'Groupe d'aliment', 'Sous-groupe d'aliment',
#        'Nom du Produit en Français', 'LCI Name', 'DQR', 'Nom et code',
#        'Agriculture', 'Transformation', 'Emballage', 'Transport',
#        'Supermarché et distribution', 'Consommation', 'Total'],
#       dtype='object', name=0)

# %%
df_detail_etape.loc[:, 'Code AGB'] = df_detail_etape['Code AGB'].astype(str)

# %%
df_detail_etape.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Code AGB                     2517 non-null   object
#  1   Code CIQUAL                  2517 non-null   object
#  2   Groupe d'aliment             2517 non-null   object
#  3   Sous-groupe d'aliment        2517 non-null   object
#  4   Nom du Produit en Français   2517 non-null   object
#  5   LCI Name                     2517 non-null   object
#  6   DQR                          2517 non-null   object
#  7   Nom et code                  2517 non-null   object
#  8   Agriculture                  2517 non-null   object
#  9   Transformation               2517 non-null   object
#  10  Emballage                    2517 non-null   object
#  11  Transport                    2517 non-null   object
#  12  Supermarché et distribution  2517 non-null   object
# ...

# %% [markdown]
# ### Vérifier si doublons dans colonnes "Code AGB" et "Code CIQUAL"

# %%
df_detail_etape['Code AGB'].astype(str) != df_detail_etape['Code CIQUAL'].astype(str)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2512    False
# 2513    False
# 2514    False
# 2515    False
# 2516    False
# Length: 2517, dtype: bool

# %%
mask_diff_AGB_CIQUAL = df_detail_etape['Code AGB'].astype(str) != df_detail_etape['Code CIQUAL'].astype(str)
all(mask_diff_AGB_CIQUAL)
# Out:
# False

# %%
df_detail_etape[mask_diff_AGB_CIQUAL][['Code AGB', 'Code CIQUAL', 'Nom du Produit en Français']]
# Out:
# 0    Code AGB Code CIQUAL                         Nom du Produit en Français
# 93      11182       11212  Sauce au poivre, condimentaire, froide, préemb...
# 443   25415_2       25415                                  Burger végétarien
# 479   25415_1       25415        Double cheeseburger, provenant de fast food
# 711    7815_2        7815                                    Wrap végétarien
# 816   13024_2       13082                            Clémentine, pulpe, crue
# 870   13014_2       13014                             Fraise de saison, crue
# 871   13014_3       13014                           Fraise hors saison, crue
# 872   13014_1       13014                                       Fraise, crue
# 909   20061_2       20061                Haricot vert importé par avion, cru
# 911   20061_1       20061                                  Haricot vert, cru
# 958   13024_1       13024                             Mandarine, pulpe, crue
# ...

# %% [markdown]
# ### Compter combien de doublon nous avons par code Ciqual

# %%
df_detail_etape[mask_diff_AGB_CIQUAL].groupby('Code CIQUAL').count()['Nom du Produit en Français']
# Out:
# Code CIQUAL
# 1029     2
# 7815     2
# 9340     2
# 9341     2
# 11212    1
# 13014    3
# 13024    1
# 13025    2
# 13082    1
# 20047    3
# 20061    2
# 20591    2
# 25415    2
# Name: Nom du Produit en Français, dtype: int64

# %% [markdown]
# ### On sauvegarde le jeu de données

# %%
 df_detail_etape.to_csv('./data/empreinte_CO2_ingredient_secteur.csv', index=False)
